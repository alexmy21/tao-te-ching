# %%
# Add the parent directory to LOAD_PATH
push!(LOAD_PATH, @__DIR__)

# Now import the module
using HllSets

# %%
hll = HllSets.HllSet{13}()
for i in 1:100
    HllSets.add!(hll, i)
end

# %%
println(HllSets.count(hll))
# Out:
# 102
